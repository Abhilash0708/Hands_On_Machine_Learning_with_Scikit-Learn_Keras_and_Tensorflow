# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhilash0708/Hands_On_Machine_Learning_with_Scikit-Learn_Keras_and_Tensorflow/blob/main/Chapter_01/01_Training_and_Running_a_Linear_Model_using_Scikit_Learn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys

# Define your repository name and the current chapter
REPO_NAME = "Hands_On_Machine_Learning_with_Scikit-Learn_Keras_and_Tensorflow"
CHAPTER = "Chapter_01"

if 'google.colab' in sys.modules:
    print("Environment: Google Colab")

    # 1. Clone the repo to get access to the main folder
    if not os.path.exists(REPO_NAME):
        # !git clone https://github.com/Abhilash0708/{REPO_NAME}.git

    # 2. Define the path to the chapter
    chapter_path = f"{REPO_NAME}/{CHAPTER}"

    # 3. Create the folder if it doesn't exist yet (This fixes the error!)
    if not os.path.exists(chapter_path):
        os.makedirs(chapter_path)
        print(f"Created new folder: {chapter_path}")

    # 4. Change directory to the specific chapter
    os.chdir(chapter_path)
    print(f"Working directory set to: {os.getcwd()}")

else:
    print("Environment: Local Jupyter Notebook")
    # Locally, Jupyter automatically sets the working directory to the notebook's folder.
    print(f"Working directory set to: {os.getcwd()}")
# Out:
# Environment: Google Colab
# Created new folder: Hands_On_Machine_Learning_with_Scikit-Learn_Keras_and_Tensorflow/Chapter_01
# Working directory set to: /content/Hands_On_Machine_Learning_with_Scikit-Learn_Keras_and_Tensorflow/Chapter_01
